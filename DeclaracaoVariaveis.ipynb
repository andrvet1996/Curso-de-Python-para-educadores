# %% [markdown]
# Declaração de variáveis

# %%
nome = "José" #string
print(nome)

# %%
num = 100     #int
print(num)

# %%
numero = 2.3  #float
print(numero)

# %%
nome = str(input("Qual é o seu nome? "))

# %%
numero = int(input("Qual é o seu ano de nascimento? "))

# %%
num = float(input("Qual foi sua nota em Biologia? "))
