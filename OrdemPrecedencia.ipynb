# %% [markdown]
# # **ORDEM DE PRECEDÊNCIA:**
#
# **1) Parêntesis**
#
# **2) Expoentes**
#
# **3) Multiplicação e divisão (esquerda para a direita)**
#
# **4) Somas e subtrações (esquerda para a direita)**

# %%
(1+2)/2
# Out:
# 1.5

# %%
1+2/2
# Out:
# 2.0

# %%
2**0*2
# Out:
# 2

# %%
2**(0*2)
# Out:
# 1

# %%
5-2+3
# Out:
# 6

# %%
5-(2+3)
# Out:
# 0
