# %% [markdown]
# Potenciação e a radiciação

# %%
pot = 2 ** 4
print(pot)

rad = 16 ** 0.5  #raiz a partir de potência
print(rad)

# %%
import math

# %%
pot = math.pow (2,4)
print(pot)

rad = math.sqrt(16)
print(rad)
